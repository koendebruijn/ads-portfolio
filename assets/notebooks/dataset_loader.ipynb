# %% [markdown]
# available_columns = 'emotion', 'gender', 'subset', 'file_path'

# %%
import os, json
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

class Loader:
    identifier = None
    
    @classmethod # returns dataframe with dataset info
    def load_dataset(cls): return None

# %% [markdown]
# # Load CREMA-D Normal

# %%
class NormalCrema(Loader):
    identifier = 'crema_normal'
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/crema'
        for file in os.listdir(path):
            component = np.array(file.replace('.', '_').split('_'))
            component = np.array([component[2], None, None, os.path.join(path, file)])
            components.append(component)
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Gender split CREMA-D Normal

# %%
class MaleSplitCrema(Loader):
    identifier = 'crema_male'
    _crema_d_female_samples = [1002,1003,1004,1006,1007,1008,1009,1010,1012,1013,1018,1020,1021,1024,1025,1028,1029,1030,1037,1043,1046,1047,1049,
          1052,1053,1054,1055,1056,1058,1060,1061,1063,1072,1073,1074,1075,1076,1078,1079,1082,1084,1089,1091]
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/crema'
        for file in os.listdir(path):
            component = np.array(file.replace('.', '_').split('_'))
            
            if int(component[0]) in cls._crema_d_female_samples:
                continue
            
            component = np.array([component[2], "Male", None, os.path.join(path, file)])
            components.append(component)
        print(len(components))
        
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %%
class FemaleSplitCrema(Loader):
    identifier = 'crema_male'
    _crema_d_female_samples = [1002,1003,1004,1006,1007,1008,1009,1010,1012,1013,1018,1020,1021,1024,1025,1028,1029,1030,1037,1043,1046,1047,1049,
          1052,1053,1054,1055,1056,1058,1060,1061,1063,1072,1073,1074,1075,1076,1078,1079,1082,1084,1089,1091]
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/crema'
        for file in os.listdir(path):
            component = np.array(file.replace('.', '_').split('_'))
            
            if int(component[0]) not in cls._crema_d_female_samples:
                continue
            
            component = np.array([component[2], "Female", None, os.path.join(path, file)])
            components.append(component)
        print(len(components))
        
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Load CREMA-D Splitted

# %%
class SplittedCrema(Loader):
    identifier = 'crema_splitted'
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/crema_splitted'
        subsets = ['Test', 'Train', 'Validate']
        for subset in subsets:
            subset_path = f'{path}/{subset}'
            for file in os.listdir(subset_path):
                component = np.array(file.replace('.', '_').split('_'))
                component = np.array([component[2], None, subset, os.path.join(subset_path, file)])
                components.append(component)
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Load RAVDESS Normal

# %%
class NormalRavdess(Loader):
    identifier = 'ravdess_normal'
    _emotion_labels = {
      '01':'"neutral"',
      '02':'calm',
      '03':'happy',
      '04':'sad',
      '05':'angry',
      '06':'fearful',
      '07':'disgust',
      '08':'surprised'
    }
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/ravdess'
        
        for file in os.listdir(path):
            component = np.array(file.replace('.', '-').split('-'))
            component = np.array([cls._emotion_labels[component[2]], None, None, os.path.join(path, file)])
            components.append(component)
            
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Gender split RAVDESS Normal

# %%
class MaleRavdess(Loader):
    identifier = 'ravdess_normal'
    _emotion_labels = {
      '01':'"neutral"',
      '02':'calm',
      '03':'happy',
      '04':'sad',
      '05':'angry',
      '06':'fearful',
      '07':'disgust',
      '08':'surprised'
    }
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/ravdess'
        
        for file in os.listdir(path):
            component = np.array(file.replace('.', '-').split('-'))
            
            if int(component[6]) % 2 == 0:
                continue
            
            component = np.array([cls._emotion_labels[component[2]], "Male", None, os.path.join(path, file)])
            components.append(component)
            
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %%
class NormalRavdess(Loader):
    identifier = 'ravdess_normal'
    _emotion_labels = {
      '01':'"neutral"',
      '02':'calm',
      '03':'happy',
      '04':'sad',
      '05':'angry',
      '06':'fearful',
      '07':'disgust',
      '08':'surprised'
    }
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/ravdess'
        
        for file in os.listdir(path):
            component = np.array(file.replace('.', '-').split('-'))
            
            if int(component[6]) % 2 != 0:
                continue
                
            component = np.array([cls._emotion_labels[component[2]], "Female", None, os.path.join(path, file)])
            components.append(component)
            
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Load RAVDESS Splitted

# %%
class SplittedRavdess(Loader):
    identifier = 'ravdess_splitted'
    
    @classmethod
    def load_dataset(cls):
        components=[]
        path = '/datc/emo/notebooks/source/datasets/ravdess_splitted'
        subsets = ['Test', 'Train', 'Validate']
        return pd.DataFrame(data=components, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Load JSON CREMA-D

# %%
class CremadPLoader(Loader):
    BASE="../datasets/json"
    identifier="Crema-d Processed Loader"
    
    @classmethod
    def load_dataset(self, variant):
        dataset = {}
        train_path=f"{self.BASE}/train/crema-d/train_{variant}_crema-d_preprocessed_data.json"
        test_path=f"{self.BASE}/test/crema-d/test_{variant}_crema-d_preprocessed_data.json"
        
        with open(train_path) as train_data:
            dataset["train"] = json.load(train_data)  
        with open(test_path) as test_data:
            dataset["test"] = json.load(test_data)   
        return dataset

# %% [markdown]
# # Load JSON RAVDESS

# %%
class RavdessPLoader(Loader):
    BASE="../datasets/json"
    identifier="Ravdess Processed Loader"
    
    @classmethod
    def load_dataset(self, variant): 
        dataset = {}
        train_path=f"{self.BASE}/train/ravdess/train_{variant}_ravdess_preprocessed_data.json"
        test_path=f"{self.BASE}/test/ravdess/test_{variant}_ravdess_preprocessed_data.json"
        
        with open(train_path) as train_data:
            dataset["train"] = json.load(train_data)    
        with open(test_path) as test_data:
            dataset["test"] = json.load(test_data)
        return dataset

# %% [markdown]
# # Load JSON COMBINED

# %%
class CombinedPLoader(Loader):
    identifier="Combined Processed Loader"
    
    @classmethod
    def load_dataset(self, variant):
        crema = CremadPLoader.load_dataset(variant)
        crema_df = pd.DataFrame.from_dict(crema)

        ravdess = RavdessPLoader.load_dataset(variant)
        ravdess_df = pd.DataFrame.from_dict(ravdess)
        
        combined_df = pd.DataFrame()
        combined_df['train'] = crema_df['train'] + ravdess_df['train']
        combined_df['test'] = crema_df['test'] + ravdess_df['test']
  
        return combined_df

# %% [markdown]
# # Load JSON Positive and Negative RAVDESS

# %%
class RavdessPosNegLoader(Loader):
    BASE="../datasets/json"
    identifier="Ravdess Positive and Negative Processed Loader"
    
    @classmethod
    def load_dataset(self, variant): 
        dataset = {}
        train_path=f"{self.BASE}/train/ravdess/PN/train_{variant}_ravdess_preprocessed_data.json"
        test_path=f"{self.BASE}/test/ravdess/PN/test_{variant}_ravdess_preprocessed_data.json"
        
        with open(train_path) as train_data:
            dataset["train"] = json.load(train_data)    
        with open(test_path) as test_data:
            dataset["test"] = json.load(test_data)
        return dataset

# %% [markdown]
# # Load JSON Positive and Negative CREMA-D

# %%
class CremadPosNegLoader(Loader):
    BASE="../datasets/json"
    identifier="Crema-d Positive and Negative Processed Loader"
    
    @classmethod
    def load_dataset(self, variant):
        dataset = {}
        train_path=f"{self.BASE}/train/crema-d/PN/train_{variant}_crema-d_preprocessed_data.json"
        test_path=f"{self.BASE}/test/crema-d/PN/test_{variant}_crema-d_preprocessed_data.json"
        
        with open(train_path) as train_data:
            dataset["train"] = json.load(train_data)  
        with open(test_path) as test_data:
            dataset["test"] = json.load(test_data)   
        return dataset

# %% [markdown]
# # Load SAVEE Normal

# %%
class NormalSAVEE(Loader):
    identifier = 'savee_normal'
    
    @classmethod
    def load_dataset(cls):
        emotion = []
        gender = []
        paths = []
        subset = []
        path = '/data/emo/notebooks/source/datasets/SAVEE/'
        for i in os.listdir(path):
                if i[-8:-6] == '_a':
                    emotion.append('angry')
                elif i[-8:-6] == '_d':
                    emotion.append('disgust')
                elif i[-8:-6] == '_f':
                    emotion.append('fear')
                elif i[-8:-6] == '_h':
                    emotion.append('happy')
                elif i[-8:-6] == '_n':
                    emotion.append('neutral')
                elif i[-8:-6] == 'sa':
                    emotion.append('sad')
                elif i[-8:-6] == 'su':
                    emotion.append('surprise')
                else:
                    emotion.append('error')
                paths.append(path + i)
                gender.append('male')
                subset.append(None)
        SAVEE_df = pd.DataFrame(emotion, columns=['emotion'])
        SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(gender, columns=['gender'])], axis=1)
        SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(subset, columns=['subset'])], axis=1)
        SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(paths, columns=['file_path'])], axis=1)
        
        return pd.DataFrame(data=SAVEE_df, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Load SAVEE Splitted

# %%
class SplittedSavee(Loader):
    identifier = 'savee_splitted'
    
    @classmethod
    def load_dataset(cls):
        emotion = []
        gender = []
        paths = []
        subsetx = []
        path = '/datc/emo/notebooks/source/datasets/savee_splitted'
        subsets = ['Test', 'Train', 'Validate']
        for subset in subsets:
            subset_path = f'{path}/{subset}'
            for i in os.listdir(subset_path):
                if i[-8:-6] == '_a':
                    emotion.append('angry')
                elif i[-8:-6] == '_d':
                    emotion.append('disgust')
                elif i[-8:-6] == '_f':
                    emotion.append('fear')
                elif i[-8:-6] == '_h':
                    emotion.append('happy')
                elif i[-8:-6] == '_n':
                    emotion.append('neutral')
                elif i[-8:-6] == 'sa':
                    emotion.append('sad')
                elif i[-8:-6] == 'su':
                    emotion.append('surprise')
                else:
                    emotion.append('error')
                paths.append(path + i)
                gender.append('male')
                subsetx.append(subset)
        SAVEE_df = pd.DataFrame(emotion, columns=['emotion'])
        SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(gender, columns=['gender'])], axis=1)
        SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(subsetx, columns=['subset'])], axis=1)
        SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(paths, columns=['file_path'])], axis=1)
        return pd.DataFrame(data=SAVEE_df, columns=['emotion','gender','subset','file_path'])

# %%
for data in SplittedSavee.load_dataset().values:
    print(data)
# Out:
# 420
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n10.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a08.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d03.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a06.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n17.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h03.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa02.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f05.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h02.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h09.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a06.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d04.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a05.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h03.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h04.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n22.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a12.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa15.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a03.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n01.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n27.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f12.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa12.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d11.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f14.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa05.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h12.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d07.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d03.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n28.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n05.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n29.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a06.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h05.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n13.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h02.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa01.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa03.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f13.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n06.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f11.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a10.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h12.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f05.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d15.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f03.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n07.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n21.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f10.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa08.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n11.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a07.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d01.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n13.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a05.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa11.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa03.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa09.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f06.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa11.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a12.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n29.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n30.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f01.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n28.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h03.wav']
# ['sad' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa10.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f08.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n17.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n20.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d09.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n30.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n13.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n07.wav']
# ['angry' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a05.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d05.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h06.wav']
# ['happy' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h11.wav']
# ['fear' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f02.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d12.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n01.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d07.wav']
# ['neutral' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n20.wav']
# ['disgust' 'male' 'Test'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d08.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d14.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h09.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d11.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a11.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n22.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n24.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f07.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa08.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa01.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f09.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n09.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a03.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h13.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h05.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f12.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa06.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa03.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d04.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f09.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa02.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a12.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa05.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a01.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a08.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n12.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a04.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f11.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa11.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f04.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h01.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n11.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a09.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa01.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n02.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f13.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h07.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h07.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d02.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h08.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d06.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d08.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a04.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n01.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa10.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa14.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d01.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n16.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa02.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a02.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h04.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d04.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a15.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h10.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a08.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n26.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n07.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa14.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n09.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h04.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n11.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n23.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n16.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h12.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h06.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f12.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa12.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa09.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h03.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h04.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n18.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n01.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f10.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa01.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d15.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n04.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n26.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n17.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n04.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a01.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h09.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d06.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n09.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h11.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f11.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d10.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa13.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n20.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n02.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d03.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a06.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a15.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n30.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h01.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n05.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n27.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n24.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n28.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa09.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d01.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f04.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n02.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa14.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d07.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n15.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa06.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa04.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n06.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h15.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a09.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n21.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a07.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d09.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n08.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f02.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n15.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n21.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f06.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n14.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n20.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d05.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n07.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n03.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa08.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h12.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h02.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n15.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n04.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa09.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f02.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n25.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n24.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h15.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f01.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n27.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h14.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h10.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa06.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d14.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n13.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d03.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n05.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a15.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a13.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a14.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a11.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa08.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f06.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n19.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n26.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a12.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n19.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n11.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n03.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n16.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f14.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a01.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f14.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n12.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n30.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a13.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d11.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n14.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f12.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n18.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h06.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n12.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n29.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n23.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f13.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a13.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n08.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa07.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d08.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a14.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h13.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa07.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n15.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h10.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa07.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f13.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n04.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f03.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n21.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa12.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a09.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a13.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h02.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f01.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h06.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n10.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa13.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h08.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f03.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h05.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a10.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n23.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f03.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n06.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d14.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a07.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa04.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d12.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n25.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a09.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f07.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h05.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a03.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n19.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d08.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d12.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa11.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h14.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a11.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f01.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d10.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h08.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n29.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h14.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h10.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d07.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f05.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a11.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa03.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f10.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f08.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f06.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n25.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d12.wav']
# ['neutral' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n27.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d15.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa13.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d02.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa15.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f09.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d06.wav']
# ['angry' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a01.wav']
# ['sad' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa07.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d02.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f11.wav']
# ['happy' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h07.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f05.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f04.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d13.wav']
# ['fear' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f10.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d05.wav']
# ['disgust' 'male' 'Train'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d01.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f15.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa12.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a15.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a02.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa14.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d09.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n23.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa05.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a08.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f04.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f07.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d13.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n22.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d15.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h11.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f02.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n26.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a14.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f15.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa04.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n18.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n28.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_a05.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_sa15.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h13.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a03.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h08.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a04.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n22.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n02.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n08.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f14.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d06.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n17.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n19.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d09.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n03.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h15.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a04.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d04.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f08.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n14.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_n03.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n09.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a14.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h09.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_h01.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n14.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h15.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d11.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_h14.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f07.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa05.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_f15.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa15.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_a02.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h11.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_sa06.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n10.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n06.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_d13.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h07.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_d05.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa10.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n18.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d02.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n24.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n25.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_h13.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_sa13.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n12.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_f08.wav']
# ['happy' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_h01.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_f09.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa04.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedKL_n08.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_n16.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_a07.wav']
# ['sad' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJE_sa02.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_d14.wav']
# ['fear' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_f15.wav']
# ['angry' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedDC_a02.wav']
# ['disgust' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_d13.wav']
# ['neutral' 'male' 'Validate'
#  '/datc/emo/notebooks/source/datasets/savee_splittedJK_n05.wav']

# %% [markdown]
# # Load TESS Normal

# %%
class NormalTESS(Loader):
    identifier = 'tess_normal'
    
    @classmethod
    def load_dataset(cls):
        emotion = []
        gender = []
        paths = []
        subset = []
        path = '/data/emo/notebooks/source/datasets/TESS/'
        for i in os.listdir(path):
            fname = os.listdir(path + i)
            for f in fname:
                if i == 'OAF_angry' or i == 'YAF_angry':
                    emotion.append('angry')
                elif i == 'OAF_disgust' or i == 'YAF_disgust':
                    emotion.append('disgust')
                elif i == 'OAF_Fear' or i == 'YAF_fear':
                    emotion.append('fear')
                elif i == 'OAF_happy' or i == 'YAF_happy':
                    emotion.append('happy')
                elif i == 'OAF_neutral' or i == 'YAF_neutral':
                    emotion.append('neutral')
                elif i == 'OAF_Pleasant_surprise' or i == 'YAF_pleasant_surprised':
                    emotion.append('surprise')
                elif i == 'OAF_Sad' or i == 'YAF_sad':
                    emotion.append('sad')
                else:
                    emotion.append('Unknown')
                paths.append(path + i + "/" + f)
                gender.append('female')
                subset.append(None)
        TESS_df = pd.DataFrame(emotion, columns=['emotion'])
        TESS_df = pd.concat([TESS_df, pd.DataFrame(gender, columns=['gender'])], axis=1)
        TESS_df = pd.concat([TESS_df, pd.DataFrame(subset, columns=['subset'])], axis=1)
        TESS_df = pd.concat([TESS_df, pd.DataFrame(paths, columns=['file_path'])], axis=1)
        
        return pd.DataFrame(data=TESS_df, columns=['emotion','gender','subset','file_path'])

# %% [markdown]
# # Load TESS Splitted

# %%
class SplittedTess(Loader):
    identifier = 'savee_splitted'
    
    @classmethod
    def load_dataset(cls):
        emotion = []
        gender = []
        paths = []
        subsetx = []
        path = '/datc/emo/notebooks/source/datasets/tess_splitted'
        subsets = ['Test', 'Train', 'Validate']
        for subset in subsets:
            subset_path = f'{path}/{subset}'
            for i in os.listdir(subset_path):
                if 'angry' in i:
                    emotion.append('angry')
                elif 'disgust' in i:
                    emotion.append('disgust')
                elif 'fear' in i:
                    emotion.append('fear')
                elif 'happy' in i:
                    emotion.append('happy')
                elif 'neutral' in i:
                    emotion.append('neutral')
                elif 'suprised' in i:
                    emotion.append('surprise')
                elif 'sad' in i:
                    emotion.append('sad')
                else:
                    emotion.append('Unknown')
                paths.append(subset_path)
                gender.append('female')
                subsetx.append(None)
        TESS_df = pd.DataFrame(emotion, columns=['emotion'])
        TESS_df = pd.concat([TESS_df, pd.DataFrame(gender, columns=['gender'])], axis=1)
        TESS_df = pd.concat([TESS_df, pd.DataFrame(subsetx, columns=['subset'])], axis=1)
        TESS_df = pd.concat([TESS_df, pd.DataFrame(paths, columns=['file_path'])], axis=1)
        return pd.DataFrame(data=TESS_df, columns=['emotion','gender','subset','file_path'])
